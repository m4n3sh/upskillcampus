# %% [markdown]
# # Data Science and Machine Learning Workflow
#
# This notebook demonstrates the basic workflow of data science and machine learning learned during the internship.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    'Age': [22, 25, 30, 35, 40],
    'Experience': [1, 3, 5, 7, 10],
    'Salary': [25000, 35000, 50000, 65000, 80000]
}

df = pd.DataFrame(data)
df
# Out:
#    Age  Experience  Salary
# 0   22           1   25000
# 1   25           3   35000
# 2   30           5   50000
# 3   35           7   65000
# 4   40          10   80000

# %%
df.describe()
# Out:
#              Age  Experience        Salary
# count   5.000000     5.00000      5.000000
# mean   30.400000     5.20000  51000.000000
# std     7.300685     3.49285  22192.341021
# min    22.000000     1.00000  25000.000000
# 25%    25.000000     3.00000  35000.000000
# 50%    30.000000     5.00000  50000.000000
# 75%    35.000000     7.00000  65000.000000
# max    40.000000    10.00000  80000.000000

# %%
plt.scatter(df['Experience'], df['Salary'])
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
plt.show()

# %% [markdown]
# This notebook covers basic data loading, exploratory data analysis, and visualization.
# It reflects the practical learning gained during the internship.
